# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
dataset =  pd.read_csv('crime_data.csv')
dataset
# Out:
#      Disposition OffenderStatus Offender_Race Offender_Gender  Offender_Age  \
# 0         CLOSED       ARRESTED         BLACK            MALE          30.0
# 1         CLOSED       ARRESTED         BLACK            MALE          30.0
# 2         CLOSED       ARRESTED         BLACK            MALE          30.0
# 3         CLOSED       ARRESTED         BLACK            MALE          30.0
# 4         CLOSED       ARRESTED         BLACK            MALE          30.0
# ...          ...            ...           ...             ...           ...
# 6633      CLOSED       ARRESTED         BLACK          FEMALE          30.0
# 6634      CLOSED       ARRESTED         WHITE          FEMALE          20.0
# 6635      CLOSED       ARRESTED         BLACK          FEMALE          26.0
# 6636      CLOSED       ARRESTED         WHITE            MALE          38.0
# 6637      CLOSED       ARRESTED         WHITE            MALE          38.0
#
# ...

# %%
x = dataset.iloc[: , :-1].values
y = dataset.iloc[: , -1].values

# %%
print(x)
# Out:
# [['CLOSED' 'ARRESTED' 'BLACK' ... 29.0 'Non-fatal' 'Supplemental Report']
#  ['CLOSED' 'ARRESTED' 'BLACK' ... 29.0 'Non-fatal' 'Supplemental Report']
#  ['CLOSED' 'ARRESTED' 'BLACK' ... 29.0 'Non-fatal' 'Supplemental Report']
#  ...
#  ['CLOSED' 'ARRESTED' 'BLACK' ... 34.0 'Non-fatal' 'Supplemental Report']
#  ['CLOSED' 'ARRESTED' 'WHITE' ... 31.0 'Non-fatal' 'Supplemental Report']
#  ['CLOSED' 'ARRESTED' 'WHITE' ... 25.0 'Non-fatal' 'Supplemental Report']]

# %%
print(y)
# Out:
# ['Theft' 'Theft' 'Theft' ... 'Violence' 'Violence' 'Violence']

# %%
print(dataset.isnull().values)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
#### Handle missing value if any

# %%
#### Encoding categorical data

# %%
#### Split the dataset in train , test & validation set
from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
#### feature scaling should be after the split
## Model spacific 
#   not every model need this
